# %%
from auxiliary import loadData_staticTargetAddrMatch, prepare_data_loaders
import numpy as np
import torch;
import torch.nn as nn
import torch.optim as optim

from matplotlib import pyplot as plt

# %%
target_adresses = ["d8:47:32:eb:6c:38",
                    "50:c7:bf:19:e6:4d",
                    "4c:77:6d:5f:dc:20"]

datajsonpath = "../experiments/exp004_20241022_sna_kadirburakerdem/data.json"
inp_rss_vals, gt_locations = loadData_staticTargetAddrMatch(datajsonpath, second_hold = 5, shuffle=False, 
                                                            target_addresses= target_adresses, snap250ms=False)

# %%
inp_rss_vals
# Out:
# array([[-66., -51., -67.],
#        [-67., -55., -69.],
#        [-63., -65., -71.],
#        ...,
#        [-63., -57., -71.],
#        [-61., -60., -69.],
#        [-65., -54., -69.]])

# %%
gt_locations
# Out:
# array([[1.7463105, 1.2628807],
#        [1.7463105, 1.2628807],
#        [1.7463105, 1.2628807],
#        ...,
#        [1.4131361, 2.8219016],
#        [1.4131361, 2.8219016],
#        [1.4131361, 2.8219016]])

# %%
gt_locations.shape, inp_rss_vals.shape
# Out:
# ((6173, 2), (6173, 3))

# %%
limit = range(6173)

plt.ylim([-5, 0])
plt.xlim([0,5])
plt.grid()
plt.plot(gt_locations[limit,0], -1*gt_locations[limit,1])

# %%
fig, axs = plt.subplots(3, 1, figsize=(15, 10))

# Titles for the subplots
titles = target_adresses

# Loop through the 3 columns (0, 1, 2) to create subplots
for i in range(3):
    # Plot the RSS values for the given limit in each subplot
    axs[i].plot(inp_rss_vals[limit, i], color="blue", label="RSS values")
    
    # Calculate the mean of the RSS values
    mean_value = np.mean(inp_rss_vals[limit, i])
    
    # Plot the mean as a horizontal line
    axs[i].axhline(y=mean_value, color="red", linestyle="--", label=f"Mean = {mean_value:.2f}")
    
    # Set title, labels, and legend for each subplot
    axs[i].set_title(titles[i])
    axs[i].set_xlabel("Sample Index")
    axs[i].set_ylabel("RSS Value")
    axs[i].legend()

# Adjust layout for better spacing between plots
plt.tight_layout()

# Display the figure with all subplots
plt.show()

# %%
limit = range(4925,5700)

plt.ylim([-5, 0])
plt.xlim([0,5])
plt.grid()
plt.plot(gt_locations[limit,0], -1*gt_locations[limit,1])

# %%
fig, axs = plt.subplots(3, 1, figsize=(15, 10))

# Titles for the subplots
titles = target_adresses

# Loop through the 3 columns (0, 1, 2) to create subplots
for i in range(3):
    # Plot the RSS values for the given limit in each subplot
    axs[i].plot(inp_rss_vals[limit, i], color="blue", label="RSS values")
    
    # Calculate the mean of the RSS values
    mean_value = np.mean(inp_rss_vals[limit, i])
    
    # Plot the mean as a horizontal line
    axs[i].axhline(y=mean_value, color="red", linestyle="--", label=f"Mean = {mean_value:.2f}")
    
    # Set title, labels, and legend for each subplot
    axs[i].set_title(titles[i])
    axs[i].set_xlabel("Sample Index")
    axs[i].set_ylabel("RSS Value")
    axs[i].legend()

# Adjust layout for better spacing between plots
plt.tight_layout()

# Display the figure with all subplots
plt.show()

# %%
limit = range(1650,2100)

plt.ylim([-5, 0])
plt.xlim([0,5])
plt.grid()
plt.plot(gt_locations[limit,0], -1*gt_locations[limit,1])

# %%
fig, axs = plt.subplots(3, 1, figsize=(15, 10))

# Titles for the subplots
titles = target_adresses

# Loop through the 3 columns (0, 1, 2) to create subplots
for i in range(3):
    # Plot the RSS values for the given limit in each subplot
    axs[i].plot(inp_rss_vals[limit, i], color="blue", label="RSS values")
    
    # Calculate the mean of the RSS values
    mean_value = np.mean(inp_rss_vals[limit, i])
    
    # Plot the mean as a horizontal line
    axs[i].axhline(y=mean_value, color="red", linestyle="--", label=f"Mean = {mean_value:.2f}")
    
    # Set title, labels, and legend for each subplot
    axs[i].set_title(titles[i])
    axs[i].set_xlabel("Sample Index")
    axs[i].set_ylabel("RSS Value")
    axs[i].legend()

# Adjust layout for better spacing between plots
plt.tight_layout()

# Display the figure with all subplots
plt.show()

# %%
limit = range(480,1050)

plt.ylim([-5, 0])
plt.xlim([0,5])
plt.grid()
plt.plot(gt_locations[limit,0], -1*gt_locations[limit,1])

# %%
fig, axs = plt.subplots(3, 1, figsize=(15, 10))

# Titles for the subplots
titles = target_adresses

# Loop through the 3 columns (0, 1, 2) to create subplots
for i in range(3):
    # Plot the RSS values for the given limit in each subplot
    axs[i].plot(inp_rss_vals[limit, i], color="blue", label="RSS values")
    
    # Calculate the mean of the RSS values
    mean_value = np.mean(inp_rss_vals[limit, i])
    
    # Plot the mean as a horizontal line
    axs[i].axhline(y=mean_value, color="red", linestyle="--", label=f"Mean = {mean_value:.2f}")
    
    # Set title, labels, and legend for each subplot
    axs[i].set_title(titles[i])
    axs[i].set_xlabel("Sample Index")
    axs[i].set_ylabel("RSS Value")
    axs[i].legend()

# Adjust layout for better spacing between plots
plt.tight_layout()

# Display the figure with all subplots
plt.show()
